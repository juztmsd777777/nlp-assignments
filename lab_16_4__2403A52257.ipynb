# %% [markdown]
# <a href="https://colab.research.google.com/github/juztmsd777777/nlp-assignments/blob/main/lab_16_4__2403A52257.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers datasets

# %%
from transformers import pipeline

# %% [markdown]
# **Sentiment Analysis**

# %%
classifier = pipeline("sentiment-analysis")
result = classifier("Hugging Face is very easy to use!")
print(result)

# %% [markdown]
# **Dataset Importing**

# %%
from datasets import load_dataset
dataset = load_dataset("imdb")
print(dataset)

# %% [markdown]
# **Using BERT Model**

# %%
from transformers import AutoTokenizer, AutoModel
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
model = AutoModel.from_pretrained("bert-base-uncased")

# %% [markdown]
# **Tokenization**

# %%
text = "Transformers are powerful models"
inputs = tokenizer(text,return_tensors="pt")
print(inputs)

# %%
outputs = model(**inputs)
cls_embedding = outputs.last_hidden_state[:, 0, :]
print(cls_embedding.shape)

# %% [markdown]
# **Text Classification Using Hugging Face**

# %%
from transformers import AutoTokenizer, AutoModel
import torch
import numpy as np
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split

# %%
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
model = AutoModel.from_pretrained("bert-base-uncased")

# %%
texts = [
    "I love this product",
    "This is amazing",
    "I am very happy",
    "I hate this",
    "This is bad",
    "Very disappointing"
]
labels = [1, 1, 1, 0, 0, 0]

# %%
def get_embedding(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True)
    outputs = model(**inputs)
    cls_embedding = outputs.last_hidden_state[:, 0, :]
    return cls_embedding.detach().numpy()[0]

# %%
X = np.array([get_embedding(t) for t in texts])
y = np.array(labels)
print("Feature shape:", X.shape)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
clf = GaussianNB()
clf.fit(X_train, y_train)

# %%
y_pred = clf.predict(X_test)
print("Predictions:", y_pred)
print("Actual:", y_test)

# %%
test_text = "This product is really good"
test_emb = get_embedding(test_text).reshape(1, -1)
prediction = clf.predict(test_emb)
print("Prediction:", "Positive" if prediction[0] == 1 else "Negative")
